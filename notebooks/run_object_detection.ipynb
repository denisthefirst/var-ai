# %% [markdown]
# ### This notebook is for running object detection.
# It imports a function detect_object_in_video from inference.py und runs the infrence on a specified video

# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd() , '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from src.modelling.inference import detect_object_in_video, scan_videos_dir

# %%
downloaded = scan_videos_dir()
print(downloaded)
# Out:
# ['heidenheim-vs-augsburg-buli-side-bottom-zoom-super-slow-motion.mp4', 'munich-vs-freiburg-buli-back-top-super-slow-motion-2nd-sit.mp4', 'munich-vs-freiburg-buli-side-opp-bot-super-slow-motion.mp4', 'munich-vs-freiburg-buli-side-opp-top-super-slow-motion.mp4', 'germany-vs-spain-uefa-euro-2024-front.mp4', 'wolfsburg-vs-munich-buli-opp-side.mp4', 'heidenheim-vs-augsburg-buli-behind-goal-realtime.mp4', 'heidenheim-vs-augsburg-buli-side-top-realtime.mp4', 'munich-vs-freiburg-buli-side-zoom-super-slow-motion.mp4', 'wolfsburg-vs-munich-buli-side.mp4', 'uruguay-vs-ghana-fifa-wc-2010-top.mp4', 'germany-vs-spain-cutted.mp4', 'augsburg-vs-bremen-buli-super-slow-motion.mp4', 'augsburg-vs-bremen-buli-slow-motion.mp4', 'st-pauli-vs-bayer-buli-side-goal.mp4', 'heidenheim-vs-augsburg-buli-side-bottom-zoom-slow-motion.mp4', 'munich-vs-freiburg-buli-side-opp-top-super-realtime-2nd-sit.mp4', 'munich-vs-freiburg-buli-side-bot-realtime.mp4', 'germany-vs-spain-uefa-euro-2024-side.mp4', 'st-pauli-vs-bayer
# ...

# %%
video_path = "../data/raw/germany-vs-spain-uefa-euro-2024-front.mp4"
output_path = "../data/object_detected"

detect_object_in_video(video_path, output_path)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/219) /home/denis/Projects/var-ai/notebooks/../data/raw/wolfsburg-vs-munich-buli-top.mp4: 384x640 14 persons, 67.3ms
# video 1/1 (frame 2/219) /home/denis/Projects/var-ai/notebooks/../data/raw/wolfsburg-vs-munich-buli-top.mp4: 384x640 14 persons, 1 sports ball, 43.8ms
# ...
