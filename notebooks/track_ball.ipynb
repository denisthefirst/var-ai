# %%
from ultralytics import YOLO
import cv2
import numpy as np
import os
import sys

# %%
project_root = os.path.abspath(os.path.join(os.getcwd() , '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

video_path = f"{project_root}/data/raw/szenario.mp4"
model_path = f"{project_root}/models/finetuned/best.pt"
output_path = f"{project_root}/data/object_detected/szenario.mp4"

# %%
model = YOLO(model_path)  
    
# Open the video
cap = cv2.VideoCapture(video_path)
if not cap.isOpened():
    print(f"Error: Could not open video {video_path}")
    

# Get video properties
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)

# %%
# This tells to later save as mp4
fourcc = cv2.VideoWriter_fourcc(*'mp4v')

# Creates an object that will write video frames into a new file
out = cv2.VideoWriter(output_path, fourcc, fps, (width, height)) 

# A list where we want to save cetner coordinates of detected ball
ball_coordinates = [] 

# Dictionary to store trajectory points for each tracked ball
ball_trajectories = {} 

# Counts the frame we are currently on 
frame_number = 0 

# This checks if the video capture is opened and if its ready
while cap.isOpened(): 

    # Ret is boolean value and true if the frame was read succesfully, frame is an actual image
    ret, frame = cap.read() 

    # This checks if ret is false, and if it is it breaks this 
    if not ret:
        break 

    # Here the results of tracking are being stored
    results = model.track(frame, conf=0.3, persist=True) 


    
    # Checks if there are any boxes saved in results for this certain frame. results is being overwritten everytime thats why results[0]
    if results[0].boxes is not None: 

        # Here all boxes are being initialized to boxes variable
        boxes = results[0].boxes 

        # Built in python function that checks if an object has a specific attribute, returns True if it has the attr
        # Boxes is an object that contains details. cls is attr we are checking for in boxes
        if hasattr(boxes, 'cls'): 

            # This assigns all detected class names to class_names variable
            class_names = results[0].names 

            # This goes through all classes in boxes 
            for i, cls_id in enumerate(boxes.cls): 

                # This saves boxes id and assigns it to cls_id
                cls_id = int(cls_id) 

                # This gets the name of the class on that specific id
                class_name = class_names[cls_id] 

                # And then this checks if one of those is 'sports ball'
                if class_name == 'sports ball': 

                    # This line gets coordinates of the ball box
                    box = boxes.xyxy[i].cpu().numpy() 

                    # x1, y1, x2, y2 -> is the format in the box and now its getting splitted into variables
                    x1, y1, x2, y2 = box 
                    
                    # Draws a rectangle aroung the detected ball
                    cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2) 

                    # Calculate center point for drawing a point
                    center_x = int((x1 + x2) / 2) 
                    center_y = int((y1 + y2) / 2)
                    
                    # Draws a dot in the middle of the rectangle
                    cv2.circle(frame, (center_x, center_y), 4, (0, 0, 255), -1) 
                    
                    # Store coordinates
                    coord_at_frame = [frame_number, center_x, center_y]
                    ball_coordinates.append(coord_at_frame)

                    track_id = 0  # Default value

                    # Only get tracking ID if available and valid
                    if hasattr(boxes, 'id') and boxes.id is not None:
                        try:
                            track_id = int(boxes.id[i])  # i-th ID
                        except (IndexError, TypeError, ValueError):
                            # Fall back to 0 if index is bad or ID is not convertible
                            track_id = 0

                    
                    # Add point to trajectory
                    if track_id not in ball_trajectories:
                        ball_trajectories[track_id] = []
                    ball_trajectories[track_id].append((center_x, center_y))

                    # Draw trajectory line
                    if len(ball_trajectories[track_id]) > 1:
                        for i in range(1, len(ball_trajectories[track_id])):
                            # Draw line from previous point to current point
                            cv2.line(frame, 
                                ball_trajectories[track_id][i-1], 
                                ball_trajectories[track_id][i], 
                                (255, 0, 0), 2)
    # This writes the current frame into output video file we created (out)
    out.write(frame) 

    # This should display a window with the current frame and its named Ball Tracking, this updates on every loop so we can see it in real time happening
    cv2.imshow('Ball Tracking', frame) 

    # This part needs to be added otherwise the window freezes and we get black screen
    if cv2.waitKey(1) & 0xFF == ord('q'): 
        break
ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 252.8ms
# Speed: 4.8ms preprocess, 252.8ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 252.0ms
# Speed: 4.6ms preprocess, 252.0ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 255.1ms
# Speed: 7.4ms preprocess, 255.1ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 260.1ms
# Speed: 5.1ms preprocess, 260.1ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 260.9ms
# Speed: 5.0ms preprocess, 260.9ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 259.0ms
# Speed: 4.7ms preprocess, 259.0ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 260.5ms
# Speed: 4.9ms preprocess, 260.5ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 254.1ms
# Speed: 7.0ms preprocess, 254.1ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 260.5ms
# Speed: 4.7ms preprocess, 260.5ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 261.6ms
# Speed: 4.9ms preprocess, 261.6ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 259.4ms
# Speed: 5.6ms preprocess, 259.4ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 261.0ms
# Speed: 5.2ms preprocess, 261.0ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 261.4ms
# Speed: 5.2ms preprocess, 261.4ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 255.5ms
# Speed: 7.1ms preprocess, 255.5ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 259.3ms
# Speed: 4.9ms preprocess, 259.3ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 259.2ms
# Speed: 4.9ms preprocess, 259.2ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 257.4ms
# Speed: 7.2ms preprocess, 257.4ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 257.6ms
# Speed: 5.1ms preprocess, 257.6ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 253.7ms
# Speed: 5.1ms preprocess, 253.7ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 258.4ms
# Speed: 5.2ms preprocess, 258.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 259.2ms
# Speed: 5.5ms preprocess, 259.2ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 257.3ms
# Speed: 6.3ms preprocess, 257.3ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 262.3ms
# Speed: 4.9ms preprocess, 262.3ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 257.6ms
# Speed: 4.7ms preprocess, 257.6ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 257.5ms
# Speed: 5.5ms preprocess, 257.5ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 258.5ms
# Speed: 4.9ms preprocess, 258.5ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 258.1ms
# Speed: 5.2ms preprocess, 258.1ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 258.3ms
# Speed: 5.0ms preprocess, 258.3ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 255.5ms
# Speed: 5.1ms preprocess, 255.5ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 258.9ms
# Speed: 4.7ms preprocess, 258.9ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 253.6ms
# Speed: 4.6ms preprocess, 253.6ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 250.3ms
# Speed: 4.9ms preprocess, 250.3ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 250.4ms
# Speed: 4.7ms preprocess, 250.4ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 260.6ms
# Speed: 6.5ms preprocess, 260.6ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 255.5ms
# Speed: 5.4ms preprocess, 255.5ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 252.3ms
# Speed: 4.7ms preprocess, 252.3ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 260.4ms
# Speed: 4.8ms preprocess, 260.4ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 255.4ms
# Speed: 7.0ms preprocess, 255.4ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 259.4ms
# Speed: 5.1ms preprocess, 259.4ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 256.5ms
# Speed: 4.7ms preprocess, 256.5ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 260.1ms
# Speed: 4.8ms preprocess, 260.1ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 254.9ms
# Speed: 4.7ms preprocess, 254.9ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 256.4ms
# Speed: 4.9ms preprocess, 256.4ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 256.2ms
# Speed: 4.7ms preprocess, 256.2ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 261.5ms
# Speed: 4.6ms preprocess, 261.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 258.0ms
# Speed: 4.8ms preprocess, 258.0ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 259.5ms
# Speed: 4.9ms preprocess, 259.5ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 257.9ms
# Speed: 5.0ms preprocess, 257.9ms inference, 2.6ms postprocess per image at shape (1, 3, 736, 1280)

# %%
# Convert coordinates to numpy array for easier manipulation
ball_coordinates = np.array(ball_coordinates)

# Save coordinates to CSV file
if len(ball_coordinates) > 0:
    coord_path = f"{project_root}/data/coordinates/ger_vs_sp_coordinates.csv"
    np.savetxt(coord_path, ball_coordinates, delimiter=',', 
                header='frame,x,y', comments='', fmt='%d')
    print(f"Ball coordinates saved to {coord_path}")
# Out:
# Ball coordinates saved to /home/chris/proj/data-science/var-ai/data/coordinates/ger_vs_sp_coordinates.csv
