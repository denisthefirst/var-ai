# %%
from ultralytics import YOLO
import cv2
import numpy as np
import os
import sys

# %%
project_root = os.path.abspath(os.path.join(os.getcwd() , '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

video_path = f"{project_root}/data/raw/germany-vs-spain-cutted.mp4"
model_path = f"{project_root}/models/finetuned/yolo11s-1280.pt"
output_path = f"{project_root}/data/object_detected/germany-vs-spain-cutted.mp4"

# %%
model = YOLO(model_path)  
    
# Open the video
cap = cv2.VideoCapture(video_path)
if not cap.isOpened():
    print(f"Error: Could not open video {video_path}")
    

# Get video properties
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)

# %%
# This tells to later save as mp4
fourcc = cv2.VideoWriter_fourcc(*'mp4v')

# Creates an object that will write video frames into a new file
out = cv2.VideoWriter(output_path, fourcc, fps, (width, height)) 

# A list where we want to save cetner coordinates of detected ball
ball_coordinates = [] 

# Dictionary to store trajectory points for each tracked ball
ball_trajectories = {} 

# Counts the frame we are currently on 
frame_number = 0 

# This checks if the video capture is opened and if its ready
while cap.isOpened(): 

    # Ret is boolean value and true if the frame was read succesfully, frame is an actual image
    ret, frame = cap.read() 

    # This checks if ret is false, and if it is it breaks this 
    if not ret:
        break 

    # Here the results of tracking are being stored
    results = model.track(frame, conf=0.5, persist=True) 

    # This writes the current frame into output video file we created (out)
    out.write(frame) 
    
    # Checks if there are any boxes saved in results for this certain frame. results is being overwritten everytime thats why results[0]
    if results[0].boxes is not None: 

        # Here all boxes are being initialized to boxes variable
        boxes = results[0].boxes 

        # Built in python function that checks if an object has a specific attribute, returns True if it has the attr
        # Boxes is an object that contains details. cls is attr we are checking for in boxes
        if hasattr(boxes, 'cls'): 

            # This assigns all detected class names to class_names variable
            class_names = results[0].names 

            # This goes through all classes in boxes 
            for i, cls_id in enumerate(boxes.cls): 

                # This saves boxes id and assigns it to cls_id
                cls_id = int(cls_id) 

                # This gets the name of the class on that specific id
                class_name = class_names[cls_id] 

                # And then this checks if one of those is 'sports ball'
                if class_name == 'sports_ball': 

                    # This line gets coordinates of the ball box
                    box = boxes.xyxy[i].cpu().numpy() 

                    # x1, y1, x2, y2 -> is the format in the box and now its getting splitted into variables
                    x1, y1, x2, y2 = box 
                    
                    # Draws a rectangle aroung the detected ball
                    cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2) 

                    # Calculate center point for drawing a point
                    center_x = int((x1 + x2) / 2) 
                    center_y = int((y1 + y2) / 2)
                    
                    # Draws a dot in the middle of the rectangle
                    cv2.circle(frame, (center_x, center_y), 4, (0, 0, 255), -1) 
                    
                    # Store coordinates
                    ball_coordinates.append([frame_number, center_x, center_y])

                    track_id = 0  # Default value

                    # Only get tracking ID if available and valid
                    if hasattr(boxes, 'id') and boxes.id is not None:
                        try:
                            track_id = int(boxes.id[i])  # i-th ID
                        except (IndexError, TypeError, ValueError):
                            # Fall back to 0 if index is bad or ID is not convertible
                            track_id = 0

                    
                    # Add point to trajectory
                    if track_id not in ball_trajectories:
                        ball_trajectories[track_id] = []
                    ball_trajectories[track_id].append((center_x, center_y))

                    # Draw trajectory line
                    if len(ball_trajectories[track_id]) > 1:
                        for i in range(1, len(ball_trajectories[track_id])):
                            # Draw line from previous point to current point
                            cv2.line(frame, 
                                ball_trajectories[track_id][i-1], 
                                ball_trajectories[track_id][i], 
                                (255, 0, 0), 2)

    # This should display a window with the current frame and its named Ball Tracking, this updates on every loop so we can see it in real time happening
    cv2.imshow('Ball Tracking', frame) 

    # This part needs to be added otherwise the window freezes and we get black screen
    if cv2.waitKey(1) & 0xFF == ord('q'): 
        break

    # Increement frme_number for one to keep track of frame number
    frame_number += 1

# This closes the video capture, if using live webcam than its a must to use realease()
cap.release() 

# This saves the output of the video and finalizes it
out.release() 
cv2.destroyAllWindows()
# Out:
# 0: 736x1280 1 sports_ball, 815.9ms
# Speed: 13.3ms preprocess, 815.9ms inference, 1.4ms postprocess per image at shape (1, 3, 736, 1280)
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in "/home/denis/Projects/var-ai/venv/lib/python3.11/site-packages/cv2/qt/plugins"
# 0: 736x1280 1 sports_ball, 583.7ms
# Speed: 17.9ms preprocess, 583.7ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 328.8ms
# Speed: 6.6ms preprocess, 328.8ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 330.7ms
# Speed: 8.0ms preprocess, 330.7ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 373.6ms
# Speed: 9.4ms preprocess, 373.6ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 355.1ms
# Speed: 12.3ms preprocess, 355.1ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 375.6ms
# Speed: 6.4ms preprocess, 375.6ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 327.9ms
# Speed: 7.7ms preprocess, 327.9ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 340.9ms
# Speed: 7.5ms preprocess, 340.9ms inference, 1.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 343.3ms
# Speed: 7.2ms preprocess, 343.3ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 459.4ms
# Speed: 6.2ms preprocess, 459.4ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 358.4ms
# Speed: 8.6ms preprocess, 358.4ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 322.3ms
# Speed: 9.3ms preprocess, 322.3ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 353.2ms
# Speed: 6.2ms preprocess, 353.2ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 317.0ms
# Speed: 6.9ms preprocess, 317.0ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 328.5ms
# Speed: 6.3ms preprocess, 328.5ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 349.2ms
# Speed: 7.3ms preprocess, 349.2ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 3 sports_balls, 307.8ms
# Speed: 5.9ms preprocess, 307.8ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 480.8ms
# Speed: 6.3ms preprocess, 480.8ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 333.9ms
# Speed: 6.7ms preprocess, 333.9ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 439.3ms
# Speed: 5.6ms preprocess, 439.3ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 315.8ms
# Speed: 10.5ms preprocess, 315.8ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 310.4ms
# Speed: 6.9ms preprocess, 310.4ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 348.3ms
# Speed: 6.3ms preprocess, 348.3ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 330.4ms
# Speed: 6.0ms preprocess, 330.4ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 333.7ms
# Speed: 7.8ms preprocess, 333.7ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 350.9ms
# Speed: 5.8ms preprocess, 350.9ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 326.3ms
# Speed: 10.9ms preprocess, 326.3ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 333.9ms
# Speed: 6.1ms preprocess, 333.9ms inference, 1.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 432.8ms
# Speed: 6.2ms preprocess, 432.8ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 324.5ms
# Speed: 10.2ms preprocess, 324.5ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 362.1ms
# Speed: 5.9ms preprocess, 362.1ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 315.7ms
# Speed: 6.3ms preprocess, 315.7ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 339.6ms
# Speed: 5.9ms preprocess, 339.6ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 331.1ms
# Speed: 6.1ms preprocess, 331.1ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 335.2ms
# Speed: 5.8ms preprocess, 335.2ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 359.9ms
# Speed: 6.0ms preprocess, 359.9ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 328.6ms
# Speed: 10.4ms preprocess, 328.6ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 318.4ms
# Speed: 6.3ms preprocess, 318.4ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 345.9ms
# Speed: 7.8ms preprocess, 345.9ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 373.9ms
# Speed: 7.2ms preprocess, 373.9ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 369.4ms
# Speed: 7.6ms preprocess, 369.4ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 330.8ms
# Speed: 5.8ms preprocess, 330.8ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 315.1ms
# Speed: 5.9ms preprocess, 315.1ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 352.1ms
# Speed: 6.4ms preprocess, 352.1ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 317.2ms
# Speed: 7.3ms preprocess, 317.2ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 367.6ms
# Speed: 6.2ms preprocess, 367.6ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 319.3ms
# Speed: 6.6ms preprocess, 319.3ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 321.2ms
# Speed: 6.1ms preprocess, 321.2ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 392.4ms
# Speed: 15.7ms preprocess, 392.4ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 318.7ms
# Speed: 6.5ms preprocess, 318.7ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 339.3ms
# Speed: 6.5ms preprocess, 339.3ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 325.6ms
# Speed: 6.4ms preprocess, 325.6ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 363.2ms
# Speed: 6.0ms preprocess, 363.2ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 353.3ms
# Speed: 6.4ms preprocess, 353.3ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 328.4ms
# Speed: 6.3ms preprocess, 328.4ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 310.9ms
# Speed: 6.2ms preprocess, 310.9ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 330.2ms
# Speed: 11.0ms preprocess, 330.2ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 321.4ms
# Speed: 6.3ms preprocess, 321.4ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 353.0ms
# Speed: 6.0ms preprocess, 353.0ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 328.7ms
# Speed: 5.9ms preprocess, 328.7ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 309.9ms
# Speed: 6.0ms preprocess, 309.9ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 347.1ms
# Speed: 5.9ms preprocess, 347.1ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 321.2ms
# Speed: 7.7ms preprocess, 321.2ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 324.1ms
# Speed: 6.2ms preprocess, 324.1ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 318.3ms
# Speed: 12.3ms preprocess, 318.3ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 332.4ms
# Speed: 5.7ms preprocess, 332.4ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 350.4ms
# Speed: 6.4ms preprocess, 350.4ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 320.4ms
# Speed: 7.8ms preprocess, 320.4ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 350.5ms
# Speed: 30.3ms preprocess, 350.5ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 354.8ms
# Speed: 10.1ms preprocess, 354.8ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 324.7ms
# Speed: 5.8ms preprocess, 324.7ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 365.2ms
# Speed: 5.9ms preprocess, 365.2ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 332.5ms
# Speed: 6.1ms preprocess, 332.5ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 340.1ms
# Speed: 9.3ms preprocess, 340.1ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 351.5ms
# Speed: 6.4ms preprocess, 351.5ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 332.0ms
# Speed: 6.2ms preprocess, 332.0ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 349.9ms
# Speed: 6.8ms preprocess, 349.9ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 324.1ms
# Speed: 5.9ms preprocess, 324.1ms inference, 1.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 319.8ms
# Speed: 7.6ms preprocess, 319.8ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 340.1ms
# Speed: 6.4ms preprocess, 340.1ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 324.5ms
# Speed: 8.7ms preprocess, 324.5ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 322.5ms
# Speed: 7.1ms preprocess, 322.5ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 357.4ms
# Speed: 6.2ms preprocess, 357.4ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 328.2ms
# Speed: 6.4ms preprocess, 328.2ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 351.9ms
# Speed: 5.7ms preprocess, 351.9ms inference, 3.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 327.6ms
# Speed: 6.2ms preprocess, 327.6ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 318.2ms
# Speed: 5.8ms preprocess, 318.2ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 342.8ms
# Speed: 6.1ms preprocess, 342.8ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 392.7ms
# Speed: 24.8ms preprocess, 392.7ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 364.5ms
# Speed: 6.8ms preprocess, 364.5ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 324.1ms
# Speed: 5.9ms preprocess, 324.1ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 315.6ms
# Speed: 6.7ms preprocess, 315.6ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 353.4ms
# Speed: 9.0ms preprocess, 353.4ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 320.3ms
# Speed: 7.0ms preprocess, 320.3ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 319.0ms
# Speed: 6.1ms preprocess, 319.0ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 335.7ms
# Speed: 11.4ms preprocess, 335.7ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 307.2ms
# Speed: 6.4ms preprocess, 307.2ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 356.6ms
# Speed: 6.7ms preprocess, 356.6ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 326.9ms
# Speed: 6.1ms preprocess, 326.9ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 323.3ms
# Speed: 9.2ms preprocess, 323.3ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 353.3ms
# Speed: 6.8ms preprocess, 353.3ms inference, 1.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 322.7ms
# Speed: 6.5ms preprocess, 322.7ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 305.2ms
# Speed: 5.9ms preprocess, 305.2ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 323.7ms
# Speed: 6.4ms preprocess, 323.7ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 319.0ms
# Speed: 6.1ms preprocess, 319.0ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 363.4ms
# Speed: 6.1ms preprocess, 363.4ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 308.4ms
# Speed: 6.5ms preprocess, 308.4ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 439.5ms
# Speed: 6.4ms preprocess, 439.5ms inference, 3.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 315.6ms
# Speed: 6.7ms preprocess, 315.6ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 331.0ms
# Speed: 6.1ms preprocess, 331.0ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 348.4ms
# Speed: 6.0ms preprocess, 348.4ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 312.8ms
# Speed: 5.7ms preprocess, 312.8ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 336.1ms
# Speed: 6.2ms preprocess, 336.1ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 363.8ms
# Speed: 5.6ms preprocess, 363.8ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 325.1ms
# Speed: 7.3ms preprocess, 325.1ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 328.0ms
# Speed: 6.6ms preprocess, 328.0ms inference, 1.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 316.5ms
# Speed: 5.9ms preprocess, 316.5ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 317.2ms
# Speed: 6.0ms preprocess, 317.2ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 355.9ms
# Speed: 6.0ms preprocess, 355.9ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 308.7ms
# Speed: 6.2ms preprocess, 308.7ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 340.2ms
# Speed: 6.1ms preprocess, 340.2ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 349.8ms
# Speed: 10.1ms preprocess, 349.8ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 324.3ms
# Speed: 7.9ms preprocess, 324.3ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 385.3ms
# Speed: 6.9ms preprocess, 385.3ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 315.9ms
# Speed: 6.1ms preprocess, 315.9ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 329.9ms
# Speed: 6.3ms preprocess, 329.9ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 489.2ms
# Speed: 6.4ms preprocess, 489.2ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 329.8ms
# Speed: 6.2ms preprocess, 329.8ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 357.0ms
# Speed: 5.9ms preprocess, 357.0ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 322.3ms
# Speed: 5.9ms preprocess, 322.3ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 308.6ms
# Speed: 5.9ms preprocess, 308.6ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 347.4ms
# Speed: 7.1ms preprocess, 347.4ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 328.3ms
# Speed: 6.8ms preprocess, 328.3ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 332.7ms
# Speed: 6.0ms preprocess, 332.7ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 333.4ms
# Speed: 6.2ms preprocess, 333.4ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 330.6ms
# Speed: 6.5ms preprocess, 330.6ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 365.6ms
# Speed: 5.8ms preprocess, 365.6ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 sports_balls, 323.1ms
# Speed: 6.3ms preprocess, 323.1ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 356.6ms
# Speed: 6.3ms preprocess, 356.6ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 323.0ms
# Speed: 6.4ms preprocess, 323.0ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 328.1ms
# Speed: 6.0ms preprocess, 328.1ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 sports_balls, 342.5ms
# Speed: 6.2ms preprocess, 342.5ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 sports_balls, 318.6ms
# Speed: 5.8ms preprocess, 318.6ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 sports_balls, 359.3ms
# Speed: 6.0ms preprocess, 359.3ms inference, 5.1ms postprocess per image at shape (1, 3, 736, 1280)

# %%
# Convert coordinates to numpy array for easier manipulation
ball_coordinates = np.array(ball_coordinates)

# Save coordinates to CSV file
if len(ball_coordinates) > 0:
    coord_path = f"{project_root}/data/coordinates/ger_vs_sp_coordinates.csv"
    np.savetxt(coord_path, ball_coordinates, delimiter=',', 
                header='frame,x,y', comments='', fmt='%d')
    print(f"Ball coordinates saved to {coord_path}")
# Out:
# Ball coordinates saved to /home/denis/Projects/var-ai/data/coordinates/ger_vs_sp_coordinates.csv
