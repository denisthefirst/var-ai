# %%
from ultralytics import YOLO
import cv2
import numpy as np
import os
import sys

# %%
project_root = os.path.abspath(os.path.join(os.getcwd() , '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

video_path = f"{project_root}/data/raw/germany-vs-spain-cutted.mp4"
model_path = f"{project_root}/models/pretrained/yolo11m.pt"
output_path = f"{project_root}/data/object_detected/germany-vs-spain-cutted.mp4"

# %%
model = YOLO(model_path)  
    
# Open the video
cap = cv2.VideoCapture(video_path)
if not cap.isOpened():
    print(f"Error: Could not open video {video_path}")
    

# Get video properties
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)

# %%
# This tells to later save as mp4
fourcc = cv2.VideoWriter_fourcc(*'mp4v')

# Creates an object that will write video frames into a new file
out = cv2.VideoWriter(output_path, fourcc, fps, (width, height)) 

# A list where we want to save cetner coordinates of detected ball
ball_coordinates = [] 

# Dictionary to store trajectory points for each tracked ball
ball_trajectories = {} 

# Counts the frame we are currently on 
frame_number = 0 

# This checks if the video capture is opened and if its ready
while cap.isOpened(): 

    # Ret is boolean value and true if the frame was read succesfully, frame is an actual image
    ret, frame = cap.read() 

    # This checks if ret is false, and if it is it breaks this 
    if not ret:
        break 

    # Here the results of tracking are being stored
    results = model.track(frame, persist=True) 

    # This writes the current frame into output video file we created (out)
    out.write(frame) 
    
    # Checks if there are any boxes saved in results for this certain frame. results is being overwritten everytime thats why results[0]
    if results[0].boxes is not None: 

        # Here all boxes are being initialized to boxes variable
        boxes = results[0].boxes 

        # Built in python function that checks if an object has a specific attribute, returns True if it has the attr
        # Boxes is an object that contains details. cls is attr we are checking for in boxes
        if hasattr(boxes, 'cls'): 

            # This assigns all detected class names to class_names variable
            class_names = results[0].names 

            # This goes through all classes in boxes 
            for i, cls_id in enumerate(boxes.cls): 

                # This saves boxes id and assigns it to cls_id
                cls_id = int(cls_id) 

                # This gets the name of the class on that specific id
                class_name = class_names[cls_id] 

                # And then this checks if one of those is 'sports ball'
                if class_name == 'sports ball': 

                    # This line gets coordinates of the ball box
                    box = boxes.xyxy[i].cpu().numpy() 

                    # x1, y1, x2, y2 -> is the format in the box and now its getting splitted into variables
                    x1, y1, x2, y2 = box 
                    
                    # Draws a rectangle aroung the detected ball
                    cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2) 

                    # Calculate center point for drawing a point
                    center_x = int((x1 + x2) / 2) 
                    center_y = int((y1 + y2) / 2)
                    
                    # Draws a dot in the middle of the rectangle
                    cv2.circle(frame, (center_x, center_y), 4, (0, 0, 255), -1) 
                    
                    # Store coordinates
                    ball_coordinates.append([frame_number, center_x, center_y])

                    # Get tracking ID (if available)
                    track_id = None
                    if hasattr(boxes, 'id'):
                        track_id = int(boxes.id[i])
                    else:
                        track_id = 0  # Default ID if tracking is not enabled
                    
                    # Add point to trajectory
                    if track_id not in ball_trajectories:
                        ball_trajectories[track_id] = []
                    ball_trajectories[track_id].append((center_x, center_y))

                    # Draw trajectory line
                    if len(ball_trajectories[track_id]) > 1:
                        for i in range(1, len(ball_trajectories[track_id])):
                            # Draw line from previous point to current point
                            cv2.line(frame, 
                                ball_trajectories[track_id][i-1], 
                                ball_trajectories[track_id][i], 
                                (255, 0, 0), 2)

    # This should display a window with the current frame and its named Ball Tracking, this updates on every loop so we can see it in real time happening
    cv2.imshow('Ball Tracking', frame) 

    # This part needs to be added otherwise the window freezes and we get black screen
    if cv2.waitKey(1) & 0xFF == ord('q'): 
        break

    # Increement frme_number for one to keep track of frame number
    frame_number += 1

# This closes the video capture, if using live webcam than its a must to use realease()
cap.release() 

# This saves the output of the video and finalizes it
out.release() 
cv2.destroyAllWindows()
# Out:
# 0: 384x640 9 persons, 1 sports ball, 281.8ms
# Speed: 2.3ms preprocess, 281.8ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in "/home/denis/Projects/var-ai/venv/lib/python3.11/site-packages/cv2/qt/plugins"
# 0: 384x640 9 persons, 1 sports ball, 330.0ms
# Speed: 12.9ms preprocess, 330.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 sports ball, 254.3ms
# Speed: 2.3ms preprocess, 254.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 sports ball, 1 baseball bat, 287.6ms
# Speed: 6.4ms preprocess, 287.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 2 sports balls, 1 baseball bat, 332.4ms
# Speed: 2.6ms preprocess, 332.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 2 sports balls, 1 baseball bat, 267.5ms
# Speed: 2.1ms preprocess, 267.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 2 sports balls, 1 baseball bat, 256.0ms
# Speed: 3.1ms preprocess, 256.0ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 2 sports balls, 1 baseball bat, 275.3ms
# Speed: 2.5ms preprocess, 275.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 2 sports balls, 279.4ms
# Speed: 2.5ms preprocess, 279.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 2 sports balls, 271.7ms
# Speed: 2.5ms preprocess, 271.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 2 sports balls, 249.1ms
# Speed: 1.6ms preprocess, 249.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 3 sports balls, 276.1ms
# Speed: 2.3ms preprocess, 276.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 2 sports balls, 239.8ms
# Speed: 2.5ms preprocess, 239.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 sports ball, 238.4ms
# Speed: 2.7ms preprocess, 238.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 sports ball, 250.2ms
# Speed: 2.1ms preprocess, 250.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 sports ball, 1 baseball bat, 237.5ms
# Speed: 1.9ms preprocess, 237.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 baseball bat, 247.5ms
# Speed: 1.7ms preprocess, 247.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 baseball bat, 228.7ms
# Speed: 5.0ms preprocess, 228.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 baseball bat, 244.5ms
# Speed: 2.4ms preprocess, 244.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 baseball bat, 232.3ms
# Speed: 2.3ms preprocess, 232.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 251.9ms
# Speed: 2.5ms preprocess, 251.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 sports ball, 239.8ms
# Speed: 2.3ms preprocess, 239.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 sports ball, 244.7ms
# Speed: 1.8ms preprocess, 244.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 2 sports balls, 239.2ms
# Speed: 2.4ms preprocess, 239.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 2 sports balls, 260.2ms
# Speed: 1.8ms preprocess, 260.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 sports ball, 279.1ms
# Speed: 2.8ms preprocess, 279.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 sports ball, 250.5ms
# Speed: 7.9ms preprocess, 250.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 sports ball, 268.7ms
# Speed: 5.6ms preprocess, 268.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 sports ball, 249.1ms
# Speed: 2.8ms preprocess, 249.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 sports ball, 249.9ms
# Speed: 2.8ms preprocess, 249.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 sports ball, 242.4ms
# Speed: 3.5ms preprocess, 242.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 sports ball, 232.3ms
# Speed: 2.4ms preprocess, 232.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 sports ball, 263.7ms
# Speed: 4.5ms preprocess, 263.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 sports ball, 259.4ms
# Speed: 2.1ms preprocess, 259.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 sports ball, 275.1ms
# Speed: 3.3ms preprocess, 275.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 sports ball, 261.0ms
# Speed: 1.9ms preprocess, 261.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 sports ball, 254.1ms
# Speed: 2.4ms preprocess, 254.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 sports ball, 264.3ms
# Speed: 2.6ms preprocess, 264.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 sports ball, 264.4ms
# Speed: 2.4ms preprocess, 264.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 frisbee, 1 sports ball, 233.1ms
# Speed: 2.1ms preprocess, 233.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 frisbee, 1 sports ball, 253.5ms
# Speed: 2.3ms preprocess, 253.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 frisbee, 1 sports ball, 273.0ms
# Speed: 1.7ms preprocess, 273.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 frisbee, 1 sports ball, 248.7ms
# Speed: 2.3ms preprocess, 248.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1
0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 257.6ms
# Speed: 2.7ms preprocess, 257.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 241.4ms
# Speed: 2.4ms preprocess, 241.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 264.5ms
# Speed: 1.9ms preprocess, 264.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 245.9ms
# Speed: 2.5ms preprocess, 245.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 260.8ms
# Speed: 2.3ms preprocess, 260.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 273.2ms
# Speed: 2.7ms preprocess, 273.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 242.0ms
# Speed: 2.8ms preprocess, 242.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 256.8ms
# Speed: 2.6ms preprocess, 256.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 sports ball, 262.9ms
# Speed: 2.5ms preprocess, 262.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 251.9ms
# Speed: 2.4ms preprocess, 251.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 sports ball, 271.2ms
# Speed: 2.9ms preprocess, 271.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 244.6ms
# Speed: 7.3ms preprocess, 244.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 244.9ms
# Speed: 2.0ms preprocess, 244.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 237.8ms
# Speed: 2.2ms preprocess, 237.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 251.4ms
# Speed: 3.3ms preprocess, 251.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 235.6ms
# Speed: 2.9ms preprocess, 235.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 235.5ms
# Speed: 1.9ms preprocess, 235.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 234.4ms
# Speed: 2.1ms preprocess, 234.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 330.1ms
# Speed: 21.9ms preprocess, 330.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 237.5ms
# Speed: 2.9ms preprocess, 237.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 238.5ms
# Speed: 2.1ms preprocess, 238.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 237.9ms
# Speed: 1.9ms preprocess, 237.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 247.6ms
# Speed: 4.1ms preprocess, 247.6ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 253.4ms
# Speed: 3.5ms preprocess, 253.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 sports ball, 257.3ms
# Speed: 3.7ms preprocess, 257.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 sports ball, 239.8ms
# Speed: 2.0ms preprocess, 239.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 sports ball, 259.2ms
# Speed: 2.0ms preprocess, 259.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 sports ball, 240.9ms
# Speed: 1.8ms preprocess, 240.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 sports ball, 240.9ms
# Speed: 11.3ms preprocess, 240.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 sports ball, 252.7ms
# Speed: 2.9ms preprocess, 252.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 sports ball, 250.5ms
# Speed: 5.3ms preprocess, 250.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 sports ball, 261.4ms
# Speed: 10.0ms preprocess, 261.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 sports ball, 259.0ms
# Speed: 2.0ms preprocess, 259.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 sports ball, 251.0ms
# Speed: 3.7ms preprocess, 251.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 sports ball, 266.0ms
# Speed: 10.4ms preprocess, 266.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 sports ball, 252.4ms
# Speed: 3.0ms preprocess, 252.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 255.5ms
# Speed: 1.9ms preprocess, 255.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 251.7ms
# Speed: 4.1ms preprocess, 251.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 273.3ms
# Speed: 2.2ms preprocess, 273.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 260.5ms
# Speed: 1.8ms preprocess, 260.5ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 249.8ms
# Speed: 1.9ms preprocess, 249.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 325.7ms
# Speed: 13.9ms preprocess, 325.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 243.9ms
# Speed: 1.9ms preprocess, 243.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 239.4ms
# Speed: 2.1ms preprocess, 239.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 236.3ms
# Speed: 1.7ms preprocess, 236.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 274.7ms
# Speed: 2.5ms preprocess, 274.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 229.1ms
# Speed: 2.5ms preprocess, 229.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)

# %%
# Convert coordinates to numpy array for easier manipulation
ball_coordinates = np.array(ball_coordinates)

# Save coordinates to CSV file
if len(ball_coordinates) > 0:
    coord_path = f"{project_root}/data/coordinates/ger_vs_sp_coordinates.csv"
    np.savetxt(coord_path, ball_coordinates, delimiter=',', 
                header='frame,x,y', comments='', fmt='%d')
    print(f"Ball coordinates saved to {coord_path}")
# Out:
# Ball coordinates saved to /home/denis/Projects/var-ai/data/coordinates/ger_vs_sp_coordinates.csv
