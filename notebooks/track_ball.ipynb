# %%
from ultralytics import YOLO
import cv2
import numpy as np
import os
import sys

# %%
project_root = os.path.abspath(os.path.join(os.getcwd() , '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

video_path = f"{project_root}/data/raw/germany-vs-spain-cutted.mp4"
model_path = f"{project_root}/models/pretrained/yolo11s.pt"
output_path = f"{project_root}/data/object_detected/germany-vs-spain-cutted.mp4"

# %%
model = YOLO(model_path)  
    
# Open the video
cap = cv2.VideoCapture(video_path)
if not cap.isOpened():
    print(f"Error: Could not open video {video_path}")
    

# Get video properties
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)

# %%
# This tells to later save as mp4
fourcc = cv2.VideoWriter_fourcc(*'mp4v')

# Creates an object that will write video frames into a new file
out = cv2.VideoWriter(output_path, fourcc, fps, (width, height)) 

# A list where we want to save cetner coordinates of detected ball
ball_coordinates = [] 

# Dictionary to store trajectory points for each tracked ball
ball_trajectories = {} 

# Counts the frame we are currently on 
frame_number = 0 

# This checks if the video capture is opened and if its ready
while cap.isOpened(): 

    # Ret is boolean value and true if the frame was read succesfully, frame is an actual image
    ret, frame = cap.read() 

    # This checks if ret is false, and if it is it breaks this 
    if not ret:
        break 

    # Here the results of tracking are being stored
    results = model.track(frame, conf=0.7, persist=True) 

    # This writes the current frame into output video file we created (out)
    out.write(frame) 
    
    # Checks if there are any boxes saved in results for this certain frame. results is being overwritten everytime thats why results[0]
    if results[0].boxes is not None: 

        # Here all boxes are being initialized to boxes variable
        boxes = results[0].boxes 

        # Built in python function that checks if an object has a specific attribute, returns True if it has the attr
        # Boxes is an object that contains details. cls is attr we are checking for in boxes
        if hasattr(boxes, 'cls'): 

            # This assigns all detected class names to class_names variable
            class_names = results[0].names 

            # This goes through all classes in boxes 
            for i, cls_id in enumerate(boxes.cls): 

                # This saves boxes id and assigns it to cls_id
                cls_id = int(cls_id) 

                # This gets the name of the class on that specific id
                class_name = class_names[cls_id] 

                # And then this checks if one of those is 'sports ball'
                if class_name == 'sports ball': 

                    # This line gets coordinates of the ball box
                    box = boxes.xyxy[i].cpu().numpy() 

                    # x1, y1, x2, y2 -> is the format in the box and now its getting splitted into variables
                    x1, y1, x2, y2 = box 
                    
                    # Draws a rectangle aroung the detected ball
                    cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2) 

                    # Calculate center point for drawing a point
                    center_x = int((x1 + x2) / 2) 
                    center_y = int((y1 + y2) / 2)
                    
                    # Draws a dot in the middle of the rectangle
                    cv2.circle(frame, (center_x, center_y), 4, (0, 0, 255), -1) 
                    
                    # Store coordinates
                    ball_coordinates.append([frame_number, center_x, center_y])

                    track_id = 0  # Default value

                    # Only get tracking ID if available and valid
                    if hasattr(boxes, 'id') and boxes.id is not None:
                        try:
                            track_id = int(boxes.id[i])  # i-th ID
                        except (IndexError, TypeError, ValueError):
                            # Fall back to 0 if index is bad or ID is not convertible
                            track_id = 0

                    
                    # Add point to trajectory
                    if track_id not in ball_trajectories:
                        ball_trajectories[track_id] = []
                    ball_trajectories[track_id].append((center_x, center_y))

                    # Draw trajectory line
                    if len(ball_trajectories[track_id]) > 1:
                        for i in range(1, len(ball_trajectories[track_id])):
                            # Draw line from previous point to current point
                            cv2.line(frame, 
                                ball_trajectories[track_id][i-1], 
                                ball_trajectories[track_id][i], 
                                (255, 0, 0), 2)

    # This should display a window with the current frame and its named Ball Tracking, this updates on every loop so we can see it in real time happening
    cv2.imshow('Ball Tracking', frame) 

    # This part needs to be added otherwise the window freezes and we get black screen
    if cv2.waitKey(1) & 0xFF == ord('q'): 
        break

    # Increement frme_number for one to keep track of frame number
    frame_number += 1

# This closes the video capture, if using live webcam than its a must to use realease()
cap.release() 

# This saves the output of the video and finalizes it
out.release() 
cv2.destroyAllWindows()
# Out:
# 0: 384x640 3 persons, 1 sports ball, 129.1ms
# Speed: 2.1ms preprocess, 129.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in "/home/denis/Projects/var-ai/venv/lib/python3.11/site-packages/cv2/qt/plugins"
# 0: 384x640 3 persons, 248.2ms
# Speed: 15.7ms preprocess, 248.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 94.8ms
# Speed: 4.0ms preprocess, 94.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 sports ball, 108.8ms
# Speed: 2.7ms preprocess, 108.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 sports ball, 96.5ms
# Speed: 2.2ms preprocess, 96.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 sports ball, 95.3ms
# Speed: 2.0ms preprocess, 95.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 sports ball, 100.8ms
# Speed: 2.7ms preprocess, 100.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 sports ball, 90.0ms
# Speed: 2.5ms preprocess, 90.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 sports ball, 103.0ms
# Speed: 1.8ms preprocess, 103.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 91.3ms
# Speed: 2.5ms preprocess, 91.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 97.8ms
# Speed: 2.3ms preprocess, 97.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 104.4ms
# Speed: 1.9ms preprocess, 104.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 99.7ms
# Speed: 5.4ms preprocess, 99.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 92.6ms
# Speed: 4.5ms preprocess, 92.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 90.2ms
# Speed: 2.8ms preprocess, 90.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 92.0ms
# Speed: 2.5ms preprocess, 92.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 93.8ms
# Speed: 1.7ms preprocess, 93.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 100.0ms
# Speed: 2.1ms preprocess, 100.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 93.0ms
# Speed: 2.2ms preprocess, 93.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 93.0ms
# Speed: 2.4ms preprocess, 93.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 97.0ms
# Speed: 1.9ms preprocess, 97.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 96.9ms
# Speed: 2.7ms preprocess, 96.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 sports ball, 92.2ms
# Speed: 1.6ms preprocess, 92.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 sports ball, 92.0ms
# Speed: 2.5ms preprocess, 92.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 sports ball, 95.5ms
# Speed: 2.4ms preprocess, 95.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 sports ball, 96.3ms
# Speed: 2.3ms preprocess, 96.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 sports ball, 101.4ms
# Speed: 1.9ms preprocess, 101.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 sports ball, 92.7ms
# Speed: 2.1ms preprocess, 92.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 sports ball, 96.7ms
# Speed: 1.7ms preprocess, 96.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 sports ball, 96.0ms
# Speed: 1.5ms preprocess, 96.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 sports ball, 118.2ms
# Speed: 14.7ms preprocess, 118.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 sports ball, 93.1ms
# Speed: 1.8ms preprocess, 93.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 sports ball, 98.0ms
# Speed: 2.3ms preprocess, 98.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 sports ball, 96.0ms
# Speed: 3.0ms preprocess, 96.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 sports ball, 98.7ms
# Speed: 5.1ms preprocess, 98.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 sports ball, 93.1ms
# Speed: 2.2ms preprocess, 93.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 92.9ms
# Speed: 1.7ms preprocess, 92.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 92.6ms
# Speed: 2.4ms preprocess, 92.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 91.7ms
# Speed: 2.9ms preprocess, 91.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 95.0ms
# Speed: 1.9ms preprocess, 95.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 96.1ms
# Speed: 2.0ms preprocess, 96.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 99.4ms
# Speed: 1.9ms preprocess, 99.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons,
1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 93.4ms
# Speed: 1.9ms preprocess, 93.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 91.2ms
# Speed: 2.2ms preprocess, 91.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 101.3ms
# Speed: 2.7ms preprocess, 101.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 129.5ms
# Speed: 5.5ms preprocess, 129.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 122.6ms
# Speed: 2.3ms preprocess, 122.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 91.9ms
# Speed: 3.4ms preprocess, 91.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 93.3ms
# Speed: 2.4ms preprocess, 93.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 90.8ms
# Speed: 2.6ms preprocess, 90.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 sports ball, 98.8ms
# Speed: 2.0ms preprocess, 98.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 94.1ms
# Speed: 2.0ms preprocess, 94.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 92.3ms
# Speed: 2.4ms preprocess, 92.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 94.1ms
# Speed: 2.2ms preprocess, 94.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 91.2ms
# Speed: 2.2ms preprocess, 91.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 91.9ms
# Speed: 2.3ms preprocess, 91.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 97.4ms
# Speed: 2.0ms preprocess, 97.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 93.5ms
# Speed: 3.7ms preprocess, 93.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 92.0ms
# Speed: 2.4ms preprocess, 92.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 97.9ms
# Speed: 1.6ms preprocess, 97.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 96.4ms
# Speed: 2.5ms preprocess, 96.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 96.0ms
# Speed: 2.9ms preprocess, 96.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 97.2ms
# Speed: 2.1ms preprocess, 97.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 91.1ms
# Speed: 3.1ms preprocess, 91.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 94.6ms
# Speed: 2.0ms preprocess, 94.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 92.8ms
# Speed: 2.5ms preprocess, 92.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 108.0ms
# Speed: 2.4ms preprocess, 108.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 93.7ms
# Speed: 2.5ms preprocess, 93.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 124.4ms
# Speed: 19.0ms preprocess, 124.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 94.2ms
# Speed: 2.8ms preprocess, 94.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 100.7ms
# Speed: 2.3ms preprocess, 100.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 92.9ms
# Speed: 2.3ms preprocess, 92.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 92.2ms
# Speed: 6.4ms preprocess, 92.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 94.5ms
# Speed: 2.7ms preprocess, 94.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 89.3ms
# Speed: 3.0ms preprocess, 89.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 91.9ms
# Speed: 2.6ms preprocess, 91.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 97.6ms
# Speed: 2.4ms preprocess, 97.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 93.8ms
# Speed: 2.4ms preprocess, 93.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 90.4ms
# Speed: 2.5ms preprocess, 90.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 101.1ms
# Speed: 2.5ms preprocess, 101.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 91.1ms
# Speed: 1.6ms preprocess, 91.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 92.1ms
# Speed: 2.1ms preprocess, 92.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 92.6ms
# Speed: 1.5ms preprocess, 92.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 92.7ms
# Speed: 1.8ms preprocess, 92.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 92.8ms
# Speed: 1.8ms preprocess, 92.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 92.3ms
# Speed: 2.1ms preprocess, 92.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 102.6ms
# Speed: 1.4ms preprocess, 102.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 101.4ms
# Speed: 1.5ms preprocess, 101.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 92.8ms
# Speed: 2.0ms preprocess, 92.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)

# %%
# Convert coordinates to numpy array for easier manipulation
ball_coordinates = np.array(ball_coordinates)

# Save coordinates to CSV file
if len(ball_coordinates) > 0:
    coord_path = f"{project_root}/data/coordinates/ger_vs_sp_coordinates.csv"
    np.savetxt(coord_path, ball_coordinates, delimiter=',', 
                header='frame,x,y', comments='', fmt='%d')
    print(f"Ball coordinates saved to {coord_path}")
# Out:
# Ball coordinates saved to /home/denis/Projects/var-ai/data/coordinates/ger_vs_sp_coordinates.csv
