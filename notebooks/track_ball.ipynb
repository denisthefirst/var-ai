# %%
from ultralytics import YOLO
import cv2
import numpy as np
import os
import sys

# %%
project_root = os.path.abspath(os.path.join(os.getcwd() , '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

video_path = f"{project_root}/data/raw/germany-vs-spain-cutted.mp4"
model_path = f"{project_root}/models/finetuned/yolo11s-1280.pt"
output_path = f"{project_root}/data/object_detected/germany-vs-spain-cutted.mp4"

# %%
model = YOLO(model_path)  
    
# Open the video
cap = cv2.VideoCapture(video_path)
if not cap.isOpened():
    print(f"Error: Could not open video {video_path}")
    

# Get video properties
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)

# %%
# This tells to later save as mp4
fourcc = cv2.VideoWriter_fourcc(*'mp4v')

# Creates an object that will write video frames into a new file
out = cv2.VideoWriter(output_path, fourcc, fps, (width, height)) 

# A list where we want to save cetner coordinates of detected ball
ball_coordinates = [] 

# Dictionary to store trajectory points for each tracked ball
ball_trajectories = {} 

# Counts the frame we are currently on 
frame_number = 0 

# This checks if the video capture is opened and if its ready
while cap.isOpened(): 

    # Ret is boolean value and true if the frame was read succesfully, frame is an actual image
    ret, frame = cap.read() 

    # This checks if ret is false, and if it is it breaks this 
    if not ret:
        break 

    # Here the results of tracking are being stored
    results = model.track(frame, conf=0.5, persist=True) 

    # This writes the current frame into output video file we created (out)
    out.write(frame) 
    
    # Checks if there are any boxes saved in results for this certain frame. results is being overwritten everytime thats why results[0]
    if results[0].boxes is not None: 

        # Here all boxes are being initialized to boxes variable
        boxes = results[0].boxes 

        # Built in python function that checks if an object has a specific attribute, returns True if it has the attr
        # Boxes is an object that contains details. cls is attr we are checking for in boxes
        if hasattr(boxes, 'cls'): 

            # This assigns all detected class names to class_names variable
            class_names = results[0].names 

            # This goes through all classes in boxes 
            for i, cls_id in enumerate(boxes.cls): 

                # This saves boxes id and assigns it to cls_id
                cls_id = int(cls_id) 

                # This gets the name of the class on that specific id
                class_name = class_names[cls_id] 

                # And then this checks if one of those is 'sports ball'
                if class_name == 'sports_ball': 

                    # This line gets coordinates of the ball box
                    box = boxes.xyxy[i].cpu().numpy() 

                    # x1, y1, x2, y2 -> is the format in the box and now its getting splitted into variables
                    x1, y1, x2, y2 = box 
                    
                    # Draws a rectangle aroung the detected ball
                    cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2) 

                    # Calculate center point for drawing a point
                    center_x = int((x1 + x2) / 2) 
                    center_y = int((y1 + y2) / 2)
                    
                    # Draws a dot in the middle of the rectangle
                    cv2.circle(frame, (center_x, center_y), 4, (0, 0, 255), -1) 
                    
                    # Store coordinates
                    ball_coordinates.append([frame_number, center_x, center_y])

                    track_id = 0  # Default value

                    # Only get tracking ID if available and valid
                    if hasattr(boxes, 'id') and boxes.id is not None:
                        try:
                            track_id = int(boxes.id[i])  # i-th ID
                        except (IndexError, TypeError, ValueError):
                            # Fall back to 0 if index is bad or ID is not convertible
                            track_id = 0

                    
                    # Add point to trajectory
                    if track_id not in ball_trajectories:
                        ball_trajectories[track_id] = []
                    ball_trajectories[track_id].append((center_x, center_y))

                    # Draw trajectory line
                    if len(ball_trajectories[track_id]) > 1:
                        for i in range(1, len(ball_trajectories[track_id])):
                            # Draw line from previous point to current point
                            cv2.line(frame, 
                                ball_trajectories[track_id][i-1], 
                                ball_trajectories[track_id][i], 
                                (255, 0, 0), 2)

    # This should display a window with the current frame and its named Ball Tracking, this updates on every loop so we can see it in real time happening
    cv2.imshow('Ball Tracking', frame) 

    # This part needs to be added otherwise the window freezes and we get black screen
    if cv2.waitKey(1) & 0xFF == ord('q'): 
        break

    # Increement frme_number for one to keep track of frame number
    frame_number += 1

# This closes the video capture, if using live webcam than its a must to use realease()
cap.release() 

# This saves the output of the video and finalizes it
out.release() 
cv2.destroyAllWindows()
# Out:
# 0: 736x1280 1 sports_ball, 481.4ms
# Speed: 7.2ms preprocess, 481.4ms inference, 1.4ms postprocess per image at shape (1, 3, 736, 1280)
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in "/home/denis/Projects/var-ai/venv/lib/python3.11/site-packages/cv2/qt/plugins"
# 0: 736x1280 1 sports_ball, 412.6ms
# Speed: 18.7ms preprocess, 412.6ms inference, 3.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 331.3ms
# Speed: 6.0ms preprocess, 331.3ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 363.2ms
# Speed: 8.4ms preprocess, 363.2ms inference, 1.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 355.5ms
# Speed: 8.4ms preprocess, 355.5ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 336.3ms
# Speed: 6.3ms preprocess, 336.3ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 336.8ms
# Speed: 5.7ms preprocess, 336.8ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 326.0ms
# Speed: 5.9ms preprocess, 326.0ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 344.2ms
# Speed: 5.8ms preprocess, 344.2ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 342.2ms
# Speed: 7.0ms preprocess, 342.2ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 369.3ms
# Speed: 6.4ms preprocess, 369.3ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 327.1ms
# Speed: 5.9ms preprocess, 327.1ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 347.9ms
# Speed: 14.3ms preprocess, 347.9ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 343.3ms
# Speed: 5.9ms preprocess, 343.3ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 323.5ms
# Speed: 5.3ms preprocess, 323.5ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 331.5ms
# Speed: 5.9ms preprocess, 331.5ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 341.8ms
# Speed: 7.0ms preprocess, 341.8ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 3 sports_balls, 328.5ms
# Speed: 6.2ms preprocess, 328.5ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 363.7ms
# Speed: 15.9ms preprocess, 363.7ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 341.4ms
# Speed: 6.6ms preprocess, 341.4ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 334.4ms
# Speed: 5.8ms preprocess, 334.4ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 474.4ms
# Speed: 7.2ms preprocess, 474.4ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 334.0ms
# Speed: 6.9ms preprocess, 334.0ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 339.1ms
# Speed: 6.2ms preprocess, 339.1ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 340.3ms
# Speed: 10.3ms preprocess, 340.3ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 333.9ms
# Speed: 8.1ms preprocess, 333.9ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 438.6ms
# Speed: 13.4ms preprocess, 438.6ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 372.6ms
# Speed: 7.8ms preprocess, 372.6ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 403.1ms
# Speed: 11.4ms preprocess, 403.1ms inference, 3.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 495.6ms
# Speed: 7.4ms preprocess, 495.6ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 423.1ms
# Speed: 43.4ms preprocess, 423.1ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 419.5ms
# Speed: 7.4ms preprocess, 419.5ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 415.2ms
# Speed: 6.9ms preprocess, 415.2ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 343.0ms
# Speed: 5.6ms preprocess, 343.0ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 350.1ms
# Speed: 7.6ms preprocess, 350.1ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 360.2ms
# Speed: 6.2ms preprocess, 360.2ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 344.4ms
# Speed: 5.4ms preprocess, 344.4ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 383.3ms
# Speed: 16.2ms preprocess, 383.3ms inference, 4.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 351.4ms
# Speed: 8.8ms preprocess, 351.4ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 366.1ms
# Speed: 7.3ms preprocess, 366.1ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 397.5ms
# Speed: 6.0ms preprocess, 397.5ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 428.3ms
# Speed: 9.4ms preprocess, 428.3ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 346.9ms
# Speed: 9.4ms preprocess, 346.9ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 362.5ms
# Speed: 6.4ms preprocess, 362.5ms inference, 1.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 473.1ms
# Speed: 11.3ms preprocess, 473.1ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 338.3ms
# Speed: 8.6ms preprocess, 338.3ms inference, 2.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 374.7ms
# Speed: 6.3ms preprocess, 374.7ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 388.0ms
# Speed: 6.6ms preprocess, 388.0ms inference, 2.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 341.9ms
# Speed: 6.3ms preprocess, 341.9ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 449.2ms
# Speed: 8.0ms preprocess, 449.2ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 416.5ms
# Speed: 7.1ms preprocess, 416.5ms inference, 2.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 476.5ms
# Speed: 6.9ms preprocess, 476.5ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 348.7ms
# Speed: 5.3ms preprocess, 348.7ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 346.7ms
# Speed: 6.6ms preprocess, 346.7ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 359.2ms
# Speed: 6.2ms preprocess, 359.2ms inference, 2.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 490.0ms
# Speed: 11.2ms preprocess, 490.0ms inference, 2.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 363.7ms
# Speed: 6.4ms preprocess, 363.7ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 428.2ms
# Speed: 6.9ms preprocess, 428.2ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 399.2ms
# Speed: 10.9ms preprocess, 399.2ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 350.2ms
# Speed: 5.9ms preprocess, 350.2ms inference, 2.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 405.7ms
# Speed: 6.1ms preprocess, 405.7ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 372.5ms
# Speed: 6.2ms preprocess, 372.5ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 347.6ms
# Speed: 6.1ms preprocess, 347.6ms inference, 1.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 403.6ms
# Speed: 6.1ms preprocess, 403.6ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 415.1ms
# Speed: 5.8ms preprocess, 415.1ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 422.0ms
# Speed: 13.0ms preprocess, 422.0ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 347.1ms
# Speed: 5.9ms preprocess, 347.1ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 348.8ms
# Speed: 22.3ms preprocess, 348.8ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 371.5ms
# Speed: 7.2ms preprocess, 371.5ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 360.0ms
# Speed: 7.6ms preprocess, 360.0ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 398.5ms
# Speed: 6.2ms preprocess, 398.5ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 691.0ms
# Speed: 7.1ms preprocess, 691.0ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 342.9ms
# Speed: 6.0ms preprocess, 342.9ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 338.5ms
# Speed: 6.0ms preprocess, 338.5ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 335.7ms
# Speed: 8.6ms preprocess, 335.7ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 343.7ms
# Speed: 6.6ms preprocess, 343.7ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 349.5ms
# Speed: 7.0ms preprocess, 349.5ms inference, 1.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 379.5ms
# Speed: 5.6ms preprocess, 379.5ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 340.2ms
# Speed: 7.4ms preprocess, 340.2ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 347.1ms
# Speed: 6.0ms preprocess, 347.1ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 331.9ms
# Speed: 6.8ms preprocess, 331.9ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 335.4ms
# Speed: 6.3ms preprocess, 335.4ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 340.2ms
# Speed: 6.6ms preprocess, 340.2ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 329.7ms
# Speed: 6.4ms preprocess, 329.7ms inference, 2.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 368.6ms
# Speed: 6.4ms preprocess, 368.6ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 342.2ms
# Speed: 6.0ms preprocess, 342.2ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 321.7ms
# Speed: 5.9ms preprocess, 321.7ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 339.0ms
# Speed: 7.0ms preprocess, 339.0ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 338.0ms
# Speed: 8.0ms preprocess, 338.0ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 334.4ms
# Speed: 8.2ms preprocess, 334.4ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 330.5ms
# Speed: 6.5ms preprocess, 330.5ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 358.9ms
# Speed: 23.5ms preprocess, 358.9ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 371.1ms
# Speed: 6.7ms preprocess, 371.1ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 340.4ms
# Speed: 6.3ms preprocess, 340.4ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 345.0ms
# Speed: 7.5ms preprocess, 345.0ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 374.4ms
# Speed: 6.3ms preprocess, 374.4ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 335.0ms
# Speed: 7.0ms preprocess, 335.0ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 332.3ms
# Speed: 6.0ms preprocess, 332.3ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 345.3ms
# Speed: 6.9ms preprocess, 345.3ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 352.0ms
# Speed: 6.7ms preprocess, 352.0ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 338.0ms
# Speed: 7.7ms preprocess, 338.0ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 346.3ms
# Speed: 5.7ms preprocess, 346.3ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 342.4ms
# Speed: 5.7ms preprocess, 342.4ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 326.1ms
# Speed: 5.9ms preprocess, 326.1ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 330.6ms
# Speed: 7.4ms preprocess, 330.6ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 333.7ms
# Speed: 6.1ms preprocess, 333.7ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 385.6ms
# Speed: 9.4ms preprocess, 385.6ms inference, 1.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 345.8ms
# Speed: 6.2ms preprocess, 345.8ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 356.7ms
# Speed: 7.7ms preprocess, 356.7ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 352.0ms
# Speed: 6.7ms preprocess, 352.0ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 368.1ms
# Speed: 5.8ms preprocess, 368.1ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 349.6ms
# Speed: 6.2ms preprocess, 349.6ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 348.0ms
# Speed: 5.8ms preprocess, 348.0ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 581.9ms
# Speed: 6.3ms preprocess, 581.9ms inference, 1.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 348.8ms
# Speed: 6.0ms preprocess, 348.8ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 334.8ms
# Speed: 5.6ms preprocess, 334.8ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 346.0ms
# Speed: 6.5ms preprocess, 346.0ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 339.5ms
# Speed: 6.6ms preprocess, 339.5ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 336.1ms
# Speed: 6.0ms preprocess, 336.1ms inference, 1.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 336.2ms
# Speed: 6.0ms preprocess, 336.2ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 385.5ms
# Speed: 6.7ms preprocess, 385.5ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 344.0ms
# Speed: 8.0ms preprocess, 344.0ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 350.0ms
# Speed: 6.4ms preprocess, 350.0ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 336.5ms
# Speed: 6.2ms preprocess, 336.5ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 333.5ms
# Speed: 6.8ms preprocess, 333.5ms inference, 1.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 345.4ms
# Speed: 6.4ms preprocess, 345.4ms inference, 1.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 342.2ms
# Speed: 6.2ms preprocess, 342.2ms inference, 1.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 377.6ms
# Speed: 6.3ms preprocess, 377.6ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 339.0ms
# Speed: 9.0ms preprocess, 339.0ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 332.1ms
# Speed: 5.9ms preprocess, 332.1ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 327.1ms
# Speed: 6.2ms preprocess, 327.1ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 330.7ms
# Speed: 6.2ms preprocess, 330.7ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 333.8ms
# Speed: 9.1ms preprocess, 333.8ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 333.8ms
# Speed: 6.1ms preprocess, 333.8ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 334.8ms
# Speed: 6.6ms preprocess, 334.8ms inference, 3.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 338.1ms
# Speed: 7.2ms preprocess, 338.1ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 485.9ms
# Speed: 13.9ms preprocess, 485.9ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 331.2ms
# Speed: 6.2ms preprocess, 331.2ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 sports_balls, 334.3ms
# Speed: 6.0ms preprocess, 334.3ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 339.7ms
# Speed: 6.0ms preprocess, 339.7ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 338.8ms
# Speed: 6.5ms preprocess, 338.8ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports_ball, 334.9ms
# Speed: 6.8ms preprocess, 334.9ms inference, 4.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 sports_balls, 334.1ms
# Speed: 6.1ms preprocess, 334.1ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 sports_balls, 343.7ms
# Speed: 5.7ms preprocess, 343.7ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 sports_balls, 338.3ms
# Speed: 6.3ms preprocess, 338.3ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)

# %%
# Convert coordinates to numpy array for easier manipulation
ball_coordinates = np.array(ball_coordinates)

# Save coordinates to CSV file
if len(ball_coordinates) > 0:
    coord_path = f"{project_root}/data/coordinates/ger_vs_sp_coordinates.csv"
    np.savetxt(coord_path, ball_coordinates, delimiter=',', 
                header='frame,x,y', comments='', fmt='%d')
    print(f"Ball coordinates saved to {coord_path}")
# Out:
# Ball coordinates saved to /home/denis/Projects/var-ai/data/coordinates/ger_vs_sp_coordinates.csv
