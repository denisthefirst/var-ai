# %%
from ultralytics import YOLO
import cv2
import numpy as np
import os
import sys

# %%
project_root = os.path.abspath(os.path.join(os.getcwd() , '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

video_path = f"{project_root}/data/raw/germany-vs-spain-cutted.mp4"
model_path = f"{project_root}/models/finetuned/yolo11s-sports-ball-img1280-freeze10-1364.pt"
output_path = f"{project_root}/data/object_detected/germany-vs-spain-cutted.mp4"

# %%
model = YOLO(model_path)  
    
# Open the video
cap = cv2.VideoCapture(video_path)
if not cap.isOpened():
    print(f"Error: Could not open video {video_path}")
    

# Get video properties
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)

# %%
# This tells to later save as mp4
fourcc = cv2.VideoWriter_fourcc(*'mp4v')

# Creates an object that will write video frames into a new file
out = cv2.VideoWriter(output_path, fourcc, fps, (width, height)) 

# A list where we want to save cetner coordinates of detected ball
ball_coordinates = [] 

# Dictionary to store trajectory points for each tracked ball
ball_trajectories = {} 

# Counts the frame we are currently on 
frame_number = 0 

# This checks if the video capture is opened and if its ready
while cap.isOpened(): 

    # Ret is boolean value and true if the frame was read succesfully, frame is an actual image
    ret, frame = cap.read() 

    # This checks if ret is false, and if it is it breaks this 
    if not ret:
        break 

    # Here the results of tracking are being stored
    results = model.track(frame, conf=0.5, persist=True) 

    # This writes the current frame into output video file we created (out)
    out.write(frame) 
    
    # Checks if there are any boxes saved in results for this certain frame. results is being overwritten everytime thats why results[0]
    if results[0].boxes is not None: 

        # Here all boxes are being initialized to boxes variable
        boxes = results[0].boxes 

        # Built in python function that checks if an object has a specific attribute, returns True if it has the attr
        # Boxes is an object that contains details. cls is attr we are checking for in boxes
        if hasattr(boxes, 'cls'): 

            # This assigns all detected class names to class_names variable
            class_names = results[0].names 

            # This goes through all classes in boxes 
            for i, cls_id in enumerate(boxes.cls): 

                # This saves boxes id and assigns it to cls_id
                cls_id = int(cls_id) 

                # This gets the name of the class on that specific id
                class_name = class_names[cls_id] 

                # And then this checks if one of those is 'sports ball'
                if class_name == 'sports ball': 

                    # This line gets coordinates of the ball box
                    box = boxes.xyxy[i].cpu().numpy() 

                    # x1, y1, x2, y2 -> is the format in the box and now its getting splitted into variables
                    x1, y1, x2, y2 = box 
                    
                    # Draws a rectangle aroung the detected ball
                    cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2) 

                    # Calculate center point for drawing a point
                    center_x = int((x1 + x2) / 2) 
                    center_y = int((y1 + y2) / 2)
                    
                    # Draws a dot in the middle of the rectangle
                    cv2.circle(frame, (center_x, center_y), 4, (0, 0, 255), -1) 
                    
                    # Store coordinates
                    ball_coordinates.append([frame_number, center_x, center_y])

                    track_id = 0  # Default value

                    # Only get tracking ID if available and valid
                    if hasattr(boxes, 'id') and boxes.id is not None:
                        try:
                            track_id = int(boxes.id[i])  # i-th ID
                        except (IndexError, TypeError, ValueError):
                            # Fall back to 0 if index is bad or ID is not convertible
                            track_id = 0

                    
                    # Add point to trajectory
                    if track_id not in ball_trajectories:
                        ball_trajectories[track_id] = []
                    ball_trajectories[track_id].append((center_x, center_y))

                    # Draw trajectory line
                    if len(ball_trajectories[track_id]) > 1:
                        for i in range(1, len(ball_trajectories[track_id])):
                            # Draw line from previous point to current point
                            cv2.line(frame, 
                                ball_trajectories[track_id][i-1], 
                                ball_trajectories[track_id][i], 
                                (255, 0, 0), 2)

    # This should display a window with the current frame and its named Ball Tracking, this updates on every loop so we can see it in real time happening
    cv2.imshow('Ball Tracking', frame) 

    # This part needs to be added otherwise the window freezes and we get black screen
    if cv2.waitKey(1) & 0xFF == ord('q'): 
        break

    # Increement frme_number for one to keep track of frame number
    frame_number += 1

# This closes the video capture, if using live webcam than its a must to use realease()
cap.release() 

# This saves the output of the video and finalizes it
out.release() 
cv2.destroyAllWindows()
# Out:
# 0: 736x1280 1 sports ball, 386.3ms
# Speed: 9.6ms preprocess, 386.3ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in "/home/denis/Projects/var-ai/venv/lib/python3.11/site-packages/cv2/qt/plugins"
# 0: 736x1280 1 sports ball, 401.5ms
# Speed: 11.1ms preprocess, 401.5ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 329.6ms
# Speed: 13.4ms preprocess, 329.6ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 339.8ms
# Speed: 6.0ms preprocess, 339.8ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 323.2ms
# Speed: 6.6ms preprocess, 323.2ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 366.3ms
# Speed: 9.1ms preprocess, 366.3ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 327.3ms
# Speed: 7.3ms preprocess, 327.3ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 338.1ms
# Speed: 7.3ms preprocess, 338.1ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 334.2ms
# Speed: 6.2ms preprocess, 334.2ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 344.3ms
# Speed: 6.7ms preprocess, 344.3ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 446.9ms
# Speed: 6.4ms preprocess, 446.9ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 348.0ms
# Speed: 6.3ms preprocess, 348.0ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 350.1ms
# Speed: 9.2ms preprocess, 350.1ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 337.8ms
# Speed: 6.0ms preprocess, 337.8ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 349.1ms
# Speed: 6.2ms preprocess, 349.1ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 339.6ms
# Speed: 6.5ms preprocess, 339.6ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 341.0ms
# Speed: 7.1ms preprocess, 341.0ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 340.7ms
# Speed: 6.4ms preprocess, 340.7ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 343.9ms
# Speed: 5.9ms preprocess, 343.9ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 344.5ms
# Speed: 7.0ms preprocess, 344.5ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 340.1ms
# Speed: 8.1ms preprocess, 340.1ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 341.2ms
# Speed: 5.9ms preprocess, 341.2ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 347.9ms
# Speed: 7.1ms preprocess, 347.9ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 353.4ms
# Speed: 6.0ms preprocess, 353.4ms inference, 1.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 368.4ms
# Speed: 12.6ms preprocess, 368.4ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 353.7ms
# Speed: 6.4ms preprocess, 353.7ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 356.9ms
# Speed: 20.2ms preprocess, 356.9ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 338.9ms
# Speed: 6.3ms preprocess, 338.9ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 355.4ms
# Speed: 6.0ms preprocess, 355.4ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 441.8ms
# Speed: 6.4ms preprocess, 441.8ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 330.3ms
# Speed: 7.2ms preprocess, 330.3ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 332.6ms
# Speed: 7.6ms preprocess, 332.6ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 334.3ms
# Speed: 5.9ms preprocess, 334.3ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 345.7ms
# Speed: 14.5ms preprocess, 345.7ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 336.2ms
# Speed: 6.4ms preprocess, 336.2ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 347.7ms
# Speed: 6.9ms preprocess, 347.7ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 357.3ms
# Speed: 6.3ms preprocess, 357.3ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 336.8ms
# Speed: 5.9ms preprocess, 336.8ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 348.1ms
# Speed: 6.5ms preprocess, 348.1ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 337.7ms
# Speed: 6.0ms preprocess, 337.7ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 356.8ms
# Speed: 7.5ms preprocess, 356.8ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 346.7ms
# Speed: 5.9ms preprocess, 346.7ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 354.6ms
# Speed: 6.2ms preprocess, 354.6ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 324.9ms
# Speed: 6.5ms preprocess, 324.9ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 529.7ms
# Speed: 7.6ms preprocess, 529.7ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 443.9ms
# Speed: 16.9ms preprocess, 443.9ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 330.0ms
# Speed: 6.3ms preprocess, 330.0ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 376.5ms
# Speed: 15.1ms preprocess, 376.5ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 472.5ms
# Speed: 8.9ms preprocess, 472.5ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 379.6ms
# Speed: 8.1ms preprocess, 379.6ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 366.9ms
# Speed: 6.9ms preprocess, 366.9ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 338.3ms
# Speed: 6.8ms preprocess, 338.3ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 326.2ms
# Speed: 6.1ms preprocess, 326.2ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 324.0ms
# Speed: 11.4ms preprocess, 324.0ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 337.9ms
# Speed: 6.8ms preprocess, 337.9ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 354.9ms
# Speed: 6.3ms preprocess, 354.9ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 351.5ms
# Speed: 6.5ms preprocess, 351.5ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 392.9ms
# Speed: 7.0ms preprocess, 392.9ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 361.9ms
# Speed: 6.2ms preprocess, 361.9ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 340.4ms
# Speed: 6.2ms preprocess, 340.4ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 329.7ms
# Speed: 5.7ms preprocess, 329.7ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 329.5ms
# Speed: 6.2ms preprocess, 329.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 329.1ms
# Speed: 8.8ms preprocess, 329.1ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 315.5ms
# Speed: 12.5ms preprocess, 315.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 348.3ms
# Speed: 11.7ms preprocess, 348.3ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 342.5ms
# Speed: 12.0ms preprocess, 342.5ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 350.6ms
# Speed: 6.8ms preprocess, 350.6ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 326.8ms
# Speed: 6.2ms preprocess, 326.8ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 442.1ms
# Speed: 6.5ms preprocess, 442.1ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 344.5ms
# Speed: 9.9ms preprocess, 344.5ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 329.4ms
# Speed: 7.1ms preprocess, 329.4ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 343.2ms
# Speed: 6.7ms preprocess, 343.2ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 329.0ms
# Speed: 6.1ms preprocess, 329.0ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 327.9ms
# Speed: 6.3ms preprocess, 327.9ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 322.6ms
# Speed: 5.7ms preprocess, 322.6ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 345.3ms
# Speed: 6.4ms preprocess, 345.3ms inference, 1.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 330.2ms
# Speed: 7.4ms preprocess, 330.2ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 332.6ms
# Speed: 6.3ms preprocess, 332.6ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 368.8ms
# Speed: 9.5ms preprocess, 368.8ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 344.9ms
# Speed: 6.2ms preprocess, 344.9ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 331.7ms
# Speed: 7.4ms preprocess, 331.7ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 349.3ms
# Speed: 16.5ms preprocess, 349.3ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 346.6ms
# Speed: 6.2ms preprocess, 346.6ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 340.4ms
# Speed: 6.3ms preprocess, 340.4ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 331.4ms
# Speed: 6.1ms preprocess, 331.4ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 367.9ms
# Speed: 8.7ms preprocess, 367.9ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 344.1ms
# Speed: 6.4ms preprocess, 344.1ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 342.9ms
# Speed: 5.9ms preprocess, 342.9ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 372.3ms
# Speed: 36.1ms preprocess, 372.3ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 339.9ms
# Speed: 6.0ms preprocess, 339.9ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 327.4ms
# Speed: 6.7ms preprocess, 327.4ms inference, 1.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 386.7ms
# Speed: 10.3ms preprocess, 386.7ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 339.7ms
# Speed: 7.5ms preprocess, 339.7ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 344.2ms
# Speed: 6.7ms preprocess, 344.2ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 333.8ms
# Speed: 6.8ms preprocess, 333.8ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 362.3ms
# Speed: 6.2ms preprocess, 362.3ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 348.4ms
# Speed: 6.5ms preprocess, 348.4ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 325.7ms
# Speed: 6.1ms preprocess, 325.7ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 337.3ms
# Speed: 6.7ms preprocess, 337.3ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 337.9ms
# Speed: 6.0ms preprocess, 337.9ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 348.1ms
# Speed: 6.7ms preprocess, 348.1ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 333.5ms
# Speed: 8.2ms preprocess, 333.5ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 334.6ms
# Speed: 6.2ms preprocess, 334.6ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 337.2ms
# Speed: 8.5ms preprocess, 337.2ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 340.0ms
# Speed: 7.9ms preprocess, 340.0ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 326.0ms
# Speed: 10.0ms preprocess, 326.0ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 349.8ms
# Speed: 7.4ms preprocess, 349.8ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 432.7ms
# Speed: 7.9ms preprocess, 432.7ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 345.5ms
# Speed: 6.8ms preprocess, 345.5ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 337.5ms
# Speed: 7.7ms preprocess, 337.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 346.1ms
# Speed: 12.5ms preprocess, 346.1ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 334.1ms
# Speed: 6.4ms preprocess, 334.1ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 345.4ms
# Speed: 6.5ms preprocess, 345.4ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 348.8ms
# Speed: 6.6ms preprocess, 348.8ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 354.8ms
# Speed: 8.7ms preprocess, 354.8ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 355.6ms
# Speed: 6.4ms preprocess, 355.6ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 337.6ms
# Speed: 9.7ms preprocess, 337.6ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 347.9ms
# Speed: 8.9ms preprocess, 347.9ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 339.5ms
# Speed: 9.0ms preprocess, 339.5ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 334.6ms
# Speed: 8.8ms preprocess, 334.6ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 328.2ms
# Speed: 6.9ms preprocess, 328.2ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 336.5ms
# Speed: 5.9ms preprocess, 336.5ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 361.1ms
# Speed: 7.2ms preprocess, 361.1ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 365.8ms
# Speed: 6.9ms preprocess, 365.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 344.7ms
# Speed: 9.3ms preprocess, 344.7ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 334.9ms
# Speed: 7.2ms preprocess, 334.9ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 362.8ms
# Speed: 13.7ms preprocess, 362.8ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 478.3ms
# Speed: 6.1ms preprocess, 478.3ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 328.6ms
# Speed: 6.3ms preprocess, 328.6ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 sports ball, 332.8ms
# Speed: 9.5ms preprocess, 332.8ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 347.6ms
# Speed: 6.7ms preprocess, 347.6ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 354.2ms
# Speed: 6.7ms preprocess, 354.2ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 364.9ms
# Speed: 8.6ms preprocess, 364.9ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 360.8ms
# Speed: 6.0ms preprocess, 360.8ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 346.2ms
# Speed: 6.5ms preprocess, 346.2ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 356.3ms
# Speed: 6.0ms preprocess, 356.3ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 365.4ms
# Speed: 6.2ms preprocess, 365.4ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 336.0ms
# Speed: 6.1ms preprocess, 336.0ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 365.9ms
# Speed: 6.0ms preprocess, 365.9ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 339.7ms
# Speed: 6.4ms preprocess, 339.7ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 332.5ms
# Speed: 6.6ms preprocess, 332.5ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 328.4ms
# Speed: 6.2ms preprocess, 328.4ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 334.0ms
# Speed: 6.8ms preprocess, 334.0ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 333.4ms
# Speed: 6.2ms preprocess, 333.4ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 323.2ms
# Speed: 6.4ms preprocess, 323.2ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)

# %%
# Convert coordinates to numpy array for easier manipulation
ball_coordinates = np.array(ball_coordinates)

# Save coordinates to CSV file
if len(ball_coordinates) > 0:
    coord_path = f"{project_root}/data/coordinates/ger_vs_sp_coordinates.csv"
    np.savetxt(coord_path, ball_coordinates, delimiter=',', 
                header='frame,x,y', comments='', fmt='%d')
    print(f"Ball coordinates saved to {coord_path}")
# Out:
# Ball coordinates saved to /home/denis/Projects/var-ai/data/coordinates/ger_vs_sp_coordinates.csv
