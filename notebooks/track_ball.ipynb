# %%
from ultralytics import YOLO
import cv2
import numpy as np
import os
import sys

# %%
project_root = os.path.abspath(os.path.join(os.getcwd() , '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

video_path = f"{project_root}/data/raw/germany-vs-spain-cutted.mp4"
model_path = f"{project_root}/models/pretrained/yolo11n.pt"
output_path = f"{project_root}/data/object_detected/germany-vs-spain-cutted.mp4"

# %%
model = YOLO(model_path)  
    
# Open the video
cap = cv2.VideoCapture(video_path)
if not cap.isOpened():
    print(f"Error: Could not open video {video_path}")
    

# Get video properties
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)

# %%
# This tells to later save as mp4
fourcc = cv2.VideoWriter_fourcc(*'mp4v')

# Creates an object that will write video frames into a new file
out = cv2.VideoWriter(output_path, fourcc, fps, (width, height)) 

# A list where we want to save cetner coordinates of detected ball
ball_coordinates = [] 

# Dictionary to store trajectory points for each tracked ball
ball_trajectories = {} 

# Counts the frame we are currently on 
frame_number = 0 

# This checks if the video capture is opened and if its ready
while cap.isOpened(): 

    # Ret is boolean value and true if the frame was read succesfully, frame is an actual image
    ret, frame = cap.read() 

    # This checks if ret is false, and if it is it breaks this 
    if not ret:
        break 

    # Here the results of tracking are being stored
    results = model.track(frame, persist=True) 

    # This writes the current frame into output video file we created (out)
    out.write(frame) 
    
    # Checks if there are any boxes saved in results for this certain frame. results is being overwritten everytime thats why results[0]
    if results[0].boxes is not None: 

        # Here all boxes are being initialized to boxes variable
        boxes = results[0].boxes 

        # Built in python function that checks if an object has a specific attribute, returns True if it has the attr
        # Boxes is an object that contains details. cls is attr we are checking for in boxes
        if hasattr(boxes, 'cls'): 

            # This assigns all detected class names to class_names variable
            class_names = results[0].names 

            # This goes through all classes in boxes 
            for i, cls_id in enumerate(boxes.cls): 

                # This saves boxes id and assigns it to cls_id
                cls_id = int(cls_id) 

                # This gets the name of the class on that specific id
                class_name = class_names[cls_id] 

                # And then this checks if one of those is 'sports ball'
                if class_name == 'sports ball': 

                    # This line gets coordinates of the ball box
                    box = boxes.xyxy[i].cpu().numpy() 

                    # x1, y1, x2, y2 -> is the format in the box and now its getting splitted into variables
                    x1, y1, x2, y2 = box 
                    
                    # Draws a rectangle aroung the detected ball
                    cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2) 

                    # Calculate center point for drawing a point
                    center_x = int((x1 + x2) / 2) 
                    center_y = int((y1 + y2) / 2)
                    
                    # Draws a dot in the middle of the rectangle
                    cv2.circle(frame, (center_x, center_y), 4, (0, 0, 255), -1) 
                    
                    # Store coordinates
                    ball_coordinates.append([frame_number, center_x, center_y])

                    # Get tracking ID (if available)
                    track_id = None
                    if hasattr(boxes, 'id'):
                        track_id = int(boxes.id[i])
                    else:
                        track_id = 0  # Default ID if tracking is not enabled
                    
                    # Add point to trajectory
                    if track_id not in ball_trajectories:
                        ball_trajectories[track_id] = []
                    ball_trajectories[track_id].append((center_x, center_y))

                    # Draw trajectory line
                    if len(ball_trajectories[track_id]) > 1:
                        for i in range(1, len(ball_trajectories[track_id])):
                            # Draw line from previous point to current point
                            cv2.line(frame, 
                                ball_trajectories[track_id][i-1], 
                                ball_trajectories[track_id][i], 
                                (255, 0, 0), 2)

    # This should display a window with the current frame and its named Ball Tracking, this updates on every loop so we can see it in real time happening
    cv2.imshow('Ball Tracking', frame) 

    # This part needs to be added otherwise the window freezes and we get black screen
    if cv2.waitKey(1) & 0xFF == ord('q'): 
        break

    # Increement frme_number for one to keep track of frame number
    frame_number += 1

# This closes the video capture, if using live webcam than its a must to use realease()
cap.release() 

# This saves the output of the video and finalizes it
out.release() 
cv2.destroyAllWindows()
# Out:
# 0: 384x640 9 persons, 1 sports ball, 1 chair, 152.3ms
# Speed: 2.6ms preprocess, 152.3ms inference, 14.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 chair, 109.3ms
# Speed: 3.6ms preprocess, 109.3ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in "/home/denis/Projects/var-ai/venv/lib/python3.11/site-packages/cv2/qt/plugins"
# 0: 384x640 8 persons, 75.3ms
# Speed: 2.2ms preprocess, 75.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 sports ball, 97.0ms
# Speed: 18.6ms preprocess, 97.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 sports ball, 1 baseball bat, 63.1ms
# Speed: 4.8ms preprocess, 63.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 sports ball, 1 baseball bat, 59.3ms
# Speed: 2.9ms preprocess, 59.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 sports ball, 1 baseball bat, 77.7ms
# Speed: 3.9ms preprocess, 77.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 sports ball, 1 baseball bat, 57.9ms
# Speed: 2.7ms preprocess, 57.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 sports ball, 1 baseball bat, 61.2ms
# Speed: 9.0ms preprocess, 61.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 sports ball, 1 baseball bat, 61.0ms
# Speed: 4.3ms preprocess, 61.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 sports ball, 1 baseball bat, 63.1ms
# Speed: 2.1ms preprocess, 63.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 baseball bat, 57.7ms
# Speed: 4.9ms preprocess, 57.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 baseball bat, 58.9ms
# Speed: 2.5ms preprocess, 58.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 baseball bat, 59.4ms
# Speed: 2.2ms preprocess, 59.4ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 baseball bat, 56.1ms
# Speed: 1.7ms preprocess, 56.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 baseball bat, 56.7ms
# Speed: 3.2ms preprocess, 56.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 baseball bat, 71.7ms
# Speed: 12.7ms preprocess, 71.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 baseball bat, 62.5ms
# Speed: 2.4ms preprocess, 62.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 baseball bat, 59.8ms
# Speed: 2.0ms preprocess, 59.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 65.8ms
# Speed: 2.6ms preprocess, 65.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 61.3ms
# Speed: 10.0ms preprocess, 61.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 52.2ms
# Speed: 4.0ms preprocess, 52.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 53.7ms
# Speed: 2.5ms preprocess, 53.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 sports ball, 61.0ms
# Speed: 1.6ms preprocess, 61.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 sports ball, 182.3ms
# Speed: 4.8ms preprocess, 182.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 sports ball, 55.6ms
# Speed: 2.0ms preprocess, 55.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 sports ball, 57.4ms
# Speed: 5.6ms preprocess, 57.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 sports ball, 56.5ms
# Speed: 4.4ms preprocess, 56.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 sports ball, 66.1ms
# Speed: 2.3ms preprocess, 66.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 sports ball, 53.5ms
# Speed: 2.6ms preprocess, 53.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 sports ball, 64.3ms
# Speed: 2.1ms preprocess, 64.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 sports ball, 52.6ms
# Speed: 1.7ms preprocess, 52.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 sports ball, 54.6ms
# Speed: 2.3ms preprocess, 54.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 sports ball, 67.9ms
# Speed: 2.4ms preprocess, 67.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 sports ball, 78.1ms
# Speed: 7.4ms preprocess, 78.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 sports ball, 73.6ms
# Speed: 2.1ms preprocess, 73.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 52.3ms
# Speed: 4.3ms preprocess, 52.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 67.9ms
# Speed: 2.7ms preprocess, 67.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 50.0ms
# Speed: 4.7ms preprocess, 50.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 sports ball, 60.8ms
# Speed: 2.0ms preprocess, 60.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 54.0ms
# Speed: 2.8ms preprocess, 54.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 54.0ms
# Speed: 2.4ms preprocess, 54.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 chair, 55.9ms
# Speed: 8.3ms preprocess, 55.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 chair, 59.6ms
# Speed: 1.8ms preprocess, 59.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 chair, 62.6ms
# Speed: 2.6ms preprocess, 62.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 chair, 58.1ms
# Speed: 2.5ms preprocess, 58.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 chair, 223.0ms
# Speed: 4.2ms preprocess, 223.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 chair, 60.8ms
# Speed: 1.8ms preprocess, 60.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1
7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 58.5ms
# Speed: 2.0ms preprocess, 58.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 70.2ms
# Speed: 4.5ms preprocess, 70.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 55.7ms
# Speed: 5.6ms preprocess, 55.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 sports ball, 78.1ms
# Speed: 3.0ms preprocess, 78.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 sports ball, 54.4ms
# Speed: 2.7ms preprocess, 54.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 sports ball, 54.6ms
# Speed: 1.8ms preprocess, 54.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 53.7ms
# Speed: 4.6ms preprocess, 53.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 53.8ms
# Speed: 2.0ms preprocess, 53.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 65.9ms
# Speed: 2.3ms preprocess, 65.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 53.9ms
# Speed: 2.1ms preprocess, 53.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 58.0ms
# Speed: 2.5ms preprocess, 58.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 58.5ms
# Speed: 2.5ms preprocess, 58.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 90.1ms
# Speed: 34.5ms preprocess, 90.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 51.8ms
# Speed: 3.4ms preprocess, 51.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 52.7ms
# Speed: 1.9ms preprocess, 52.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 sports ball, 54.3ms
# Speed: 2.0ms preprocess, 54.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 sports ball, 60.3ms
# Speed: 3.2ms preprocess, 60.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 sports ball, 62.0ms
# Speed: 6.5ms preprocess, 62.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 57.7ms
# Speed: 2.3ms preprocess, 57.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 53.2ms
# Speed: 1.9ms preprocess, 53.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 61.7ms
# Speed: 3.6ms preprocess, 61.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 61.6ms
# Speed: 2.4ms preprocess, 61.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 54.5ms
# Speed: 1.8ms preprocess, 54.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 59.1ms
# Speed: 1.7ms preprocess, 59.1ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 56.6ms
# Speed: 2.5ms preprocess, 56.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 75.7ms
# Speed: 3.0ms preprocess, 75.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 52.0ms
# Speed: 8.2ms preprocess, 52.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 52.4ms
# Speed: 2.0ms preprocess, 52.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 baseball glove, 59.6ms
# Speed: 2.3ms preprocess, 59.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 59.6ms
# Speed: 4.0ms preprocess, 59.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 53.2ms
# Speed: 2.0ms preprocess, 53.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 52.2ms
# Speed: 1.8ms preprocess, 52.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 165.9ms
# Speed: 2.2ms preprocess, 165.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 52.0ms
# Speed: 2.0ms preprocess, 52.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 47.7ms
# Speed: 2.2ms preprocess, 47.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 55.2ms
# Speed: 1.6ms preprocess, 55.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 62.7ms
# Speed: 1.8ms preprocess, 62.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 55.5ms
# Speed: 1.5ms preprocess, 55.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 54.5ms
# Speed: 1.6ms preprocess, 54.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 89.5ms
# Speed: 1.8ms preprocess, 89.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 56.7ms
# Speed: 1.9ms preprocess, 56.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 62.2ms
# Speed: 1.8ms preprocess, 62.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)

# %%
'''
# Convert coordinates to numpy array for easier manipulation
ball_coordinates = np.array(ball_coordinates)

# Save coordinates to CSV file
if save_video and len(ball_coordinates) > 0:
    coord_path = os.path.splitext(output_path)[0] + '_coordinates.csv'
    np.savetxt(coord_path, ball_coordinates, delimiter=',', 
                header='frame,x,y', comments='', fmt='%d')
    print(f"Ball coordinates saved to {coord_path}")
'''
# Out:
# '\n# Convert coordinates to numpy array for easier manipulation\nball_coordinates = np.array(ball_coordinates)\n\n# Save coordinates to CSV file\nif save_video and len(ball_coordinates) > 0:\n    coord_path = os.path.splitext(output_path)[0] + \'_coordinates.csv\'\n    np.savetxt(coord_path, ball_coordinates, delimiter=\',\', \n                header=\'frame,x,y\', comments=\'\', fmt=\'%d\')\n    print(f"Ball coordinates saved to {coord_path}")\n'
